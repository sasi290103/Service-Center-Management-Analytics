# %% [markdown]
# ### loading data ###

# %%
# %sql
use catalog service_center
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
import dlt
from pyspark.sql.functions import *

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="customer data"
)
def bronze_customer():
df=spark.read.table("service_center.bronze_schema.customer_data")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_customer</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Registration_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Customer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Contact_Number</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Pincode</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Email_ID</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="sales data"
)
def bronze_sales():
df=spark.read.table("service_center.bronze_schema.sales_data")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_sales</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Dealer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Vehicle_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Temporary_Registration_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Base_Price</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Base_Price_Tax</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Discount_Price</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Parts_Added</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Parts_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Parts_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Cost</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Service_Tax</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Final_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Tags</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="branch conveniance score"
)
def bronze_branch_conveniance_score():
df=spark.read.table("service_center.bronze_schema.branch_conveniance_score")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_branch_conveniance_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_Type</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Established_Year</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Address</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>District</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>State</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Pincode</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Branch_Landline</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Inventory_Capacity</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>inventory_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Workshop_Area_sqft</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>workshop_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Number_of_Employees</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Normalizationa_employee</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>normalization_service_day</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Monthly_Revenue</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Vehicles_Serviced</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Customer_Satisfaction_Score</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>customer_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Distance_km</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>km_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>convience_score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="service center6 raw data"
)
def bronze_service_center():
df=spark.read.table("service_center.bronze_schema.service_centre")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_service_center</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>WorkOrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Number_of_Visits</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>Start_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Expected_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Actual_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Delay_Days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Speciality</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Parts_Added</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Individual_Parts_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Customer_Feedback</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Delayed_Reason</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Previous_Service_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Individual_Parts_Cost</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="sucess score"
)
def bronze_sucess_score():
df=spark.read.table("service_center.bronze_schema.success_score")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_sucess_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Dealer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Start_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Expected_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Actual_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Delay_Days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Average_Delays</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Average_Delays</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Number_of_Visits</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Visit_Count</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Visit_Count</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Average_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Average_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Branch_Convenience_Score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"bronze"},
comment="vehcile data"
)
def bronze_vehicle():
df=spark.read.table("service_center.bronze_schema.vehicle_data")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_vehicle</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Vehicle_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Make</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Year</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Body_Type</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Engine_Type</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Color</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Mileage</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Fuel_Type</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>avg_price_lakh</td>
#    <td>float</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"silver"},
comment="customer data"
)
@dlt.expect_or_drop("customer_id is not null", "customer_id IS NOT NULL")
def silver_customer():
df=dlt.read("bronze_customer")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_customer</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Registration_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Customer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Contact_Number</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Pincode</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Email_ID</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"silver"},
comment="sales data"
)
@dlt.expect_or_drop("valid_chassis", "Chassis_Number IS NOT NULL")
def silver_sales():
df=dlt.read("bronze_sales")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_sales</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Dealer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Vehicle_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Temporary_Registration_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Base_Price</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Base_Price_Tax</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Discount_Price</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Parts_Added</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Parts_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Parts_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Cost</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Service_Tax</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Final_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Tags</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={"quality":"silver"},
comment="silver service center"
)
@dlt.expect_or_drop("cutomer_id is not null", "customer_id IS NOT NULL")
def service_center_silver():
df=dlt.read("bronze_service_center")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>service_center_silver</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>WorkOrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Number_of_Visits</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>Start_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Expected_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Actual_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Delay_Days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Speciality</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Parts_Added</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Individual_Parts_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Tax</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Customer_Feedback</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Delayed_Reason</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Previous_Service_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Individual_Parts_Cost</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
import dlt
@dlt.view(
comment="customer sales"
)
def customer_sales():
df1 = dlt.read("silver_customer").select("Chassis_Number","Location")
df2 = dlt.read("silver_sales").select(
"Chassis_Number",
"Branch_id",
"Vehicle_ID",
"Model",
"Temporary_Registration_Number",
"Invoice_Date",
"Tags",
"Final_Price",
"customer_id"
)
# Inner join on Chassis_Number and select relevant fields
df_final = df2.join(df1, df1.Chassis_Number == df2.Chassis_Number, "inner") \
.select(
df2.Chassis_Number,
df2.Branch_id,
df2.Vehicle_ID,
df2.Model,
df2.Temporary_Registration_Number,
df2.Invoice_Date,
df2.Tags,
df2.Final_Price,
df2.customer_id,
df1.Location
)
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customer_sales</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Vehicle_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Temporary_Registration_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Tags</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Final_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import sum

# %%
@dlt.table(
table_properties={"quality":"gold"},
comment="sales agrregated branch wise"
)
def gold_sales_branch_wise():
df=dlt.read("customer_sales")
df_final=df.groupBy("Branch_id").agg(sum("Final_Price").alias("total_sales_branchwise"))
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_sales_branch_wise</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>total_sales_branchwise</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import col
import dlt
@dlt.view(
comment="not visited service center"
)
def customer_not_visited():
df1 = dlt.read("silver_customer").select("Chassis_Number", "customer_id", "Branch_id")
df2 = dlt.read("service_center_silver").select("Chassis_Number")
df_final = df1.join(
df2,
df1["Chassis_Number"] == df2["Chassis_Number"],
"left_anti"
).select(
df1.Chassis_Number,
df1.customer_id,
df1.Branch_id
)
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customer_not_visited</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_id</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
import dlt
from pyspark.sql.functions import col
@dlt.view(
comment="Customer and service center merged data"
)
def customer_service_center():
df1 = dlt.read("silver_customer").select("Chassis_Number", "Invoice_Date","Location","Customer_Name","Email_ID")
df2 = dlt.read("service_center_silver").select(
"Chassis_Number",
"customer_id",
"Branch_ID",
"Model",
"Speciality",
"Parts_Added",
"Total_Price",
"Previous_Service_Date"
)
df_final = df2.join(
df1,
df2["Chassis_Number"] == df1["Chassis_Number"],
"inner"
).select(
df2["Chassis_Number"],
df2["customer_id"],
df2["Branch_ID"],
df2["Model"],
df2["Speciality"],
df2["Parts_Added"],
df2["Total_Price"],
df1["Invoice_Date"],
df2["Previous_Service_Date"],
df1["Location"],
df1["Customer_Name"],
df1["Email_ID"]
)
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customer_service_center</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Chassis_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Speciality</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Parts_Added</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Invoice_Date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Previous_Service_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Customer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Email_ID</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
# from pyspark.sql.functions import col, datediff, current_timestamp
# @dlt.table(
#     comment="Customers who have not visited the service center in the last 120 days"
# )
# def not_visited_120_days():
#     df = dlt.read("customer_service_center")
#     df = df.withColumn("Previous_Service_Date", col("Previous_Service_Date").cast("timestamp")) \
#            .select("Previous_Service_Date", "Customer_Name", "Email_ID", "Branch_ID", "customer_id")
#     df_filtered = df.filter(
#         datediff(current_timestamp(), col("Previous_Service_Date")) > 120
#     )
#     df_result = df_filtered.dropna().distinct()
#     return df_result
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>visited_120_days</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import col, datediff, current_date, max as spark_max
@dlt.table(
comment="Customers who have visited the service center in the last 120 days"
)
def visited_120_days():
df = dlt.read("customer_service_center")
df = df.withColumn("Previous_Service_Date", col("Previous_Service_Date").cast("date")) \
.select("customer_id", "Customer_Name", "Email_ID", "Branch_ID", "Previous_Service_Date")
latest_service = df.groupBy("customer_id").agg(
spark_max("Previous_Service_Date").alias("Last_Service_Date")
)
inactive_customers = latest_service.filter(
datediff(current_date(), col("Last_Service_Date")) <= 120
)
final_result = inactive_customers.join(df, on="customer_id", how="left") \
.select("customer_id", "Customer_Name", "Email_ID", "Branch_ID", "Last_Service_Date") \
.dropDuplicates(["customer_id"])
return final_result
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>not_visited_120_days</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Previous_Service_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Customer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Email_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import col, datediff, current_date, max as spark_max
@dlt.table(
comment="Customers who have not visited the service center in the last 120 days"
)
def not_visited_120_days():
df = dlt.read("customer_service_center")
df = df.withColumn("Previous_Service_Date", col("Previous_Service_Date").cast("date")) \
.select("customer_id", "Customer_Name", "Email_ID", "Branch_ID", "Previous_Service_Date","Model")
latest_service = df.groupBy("customer_id").agg(
spark_max("Previous_Service_Date").alias("Last_Service_Date")
)
inactive_customers = latest_service.filter(
datediff(current_date(), col("Last_Service_Date")) > 120
)
final_result = inactive_customers.join(df, on="customer_id", how="left") \
.select("customer_id", "Customer_Name", "Email_ID", "Branch_ID", "Last_Service_Date","Model") \
.dropDuplicates(["customer_id"])
return final_result

# %%
# from pyspark.sql.functions import col, datediff, current_timestamp
# @dlt.table(
#     comment="Customers who have not visited the service center in the last 120 days"
# )
# def not_visited_120_days():
#     df = dlt.read("customer_service_center")
#     df = df.withColumn("Previous_Service_Date", col("Previous_Service_Date").cast("timestamp")) \
#            .select("Previous_Service_Date", "Customer_Name", "Email_ID", "Branch_ID", "customer_id")
#     df_filtered = df.filter(
#         datediff(current_timestamp(), col("Previous_Service_Date")) > 120
#     )
#     df_result = df_filtered.dropna().distinct()
#     return df_result

# %%
# @dlt.table(
#     comment="Customers who not visited within 120 days"
# )
# def not_visited_120_days():
#     df = dlt.read("customer_service_center")
#     df = df.withColumn("Previous_Service_Date", col("Previous_Service_Date").cast("timestamp"))
#     df_final = df.filter(
#         datediff(current_timestamp(), col("Previous_Service_Date")) > 120
#     )
#     df_final=df_final.groupBy("Branch_ID","customer_id").agg(sum("Branch_ID").alias("sum"))
#     df_final =df_final.select("Branch_ID", "customer_id").dropna()
#     return df_final

# %%
# @dlt.table(
#     comment="Visited_120days_Customer_Details"
# )
# def gold_Visited_120days_Customer_Details():
#     df=dlt.read("visited_120_days")
#     final_df=df.groupBy("Branch_ID","customer_id").agg(sum("Branch_ID").alias("sum"))
#     final_df = final_df.select("Branch_ID", "customer_id").dropna()
#     return final_df

# %%
# @dlt.table(
#     comment="not_visited_120_days_customer_details"
# )
# def gold_not_visited_120_days_customer_details():
#     df=dlt.read("not_visited_120_days")
#     final_df=df.groupBy("Branch_ID","customer_id").agg(sum("Branch_ID").alias("sum"))
#     final_df = final_df.select("Branch_ID", "customer_id").dropna()
#     return final_df

# %%
@dlt.table(
table_properties={"quality":"silver"},
comment="silver_success_score"
)
def silver_success_score():
df=dlt.read("bronze_sucess_score")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_success_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Dealer_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Start_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Expected_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Actual_Date</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>Delay_Days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Average_Delays</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Average_Delays</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Number_of_Visits</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Visit_Count</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Visit_Count</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Average_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Normalized_Average_Cost</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Branch_Convenience_Score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={'quality':'gold'},
comment="gold_success_score"
)
def gold_success_score():
df=dlt.read("silver_success_score")
df_final=df.groupBy(["Branch_ID","Model","Branch_Convenience_Score"]).agg(sum("Branch_Convenience_Score").alias("overall_score"))
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_success_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_Convenience_Score</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>overall_score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
table_properties={'quality':'silver'},
comment="silver_brach_convenience_score"
)
def silver_branch_convenience_score():
df=dlt.read("bronze_branch_conveniance_score")
return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_branch_convenience_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_Type</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Established_Year</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Address</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>District</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>State</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Pincode</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Branch_Landline</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Inventory_Capacity</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>inventory_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Workshop_Area_sqft</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>workshop_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Number_of_Employees</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Normalizationa_employee</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_days</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>normalization_service_day</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Monthly_Revenue</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Vehicles_Serviced</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Customer_Satisfaction_Score</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>customer_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Service_Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Branch_Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Distance_km</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>km_normalization</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>convience_score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import sum
import dlt
@dlt.table(
comment="Gold level: branch-wise overall convenience score"
)
def gold_branch_convenience_score():
df = dlt.read("silver_branch_convenience_score")
df_final = df.groupBy("Branch_ID") \
.agg(sum("convience_score").alias("overall_score"))
return df_final
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_branch_convenience_score</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>overall_score</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Location_Wise_Sales"
)
def gold_location_wise_sales():
df=dlt.read("customer_sales")
final_df=df.groupBy("Location").agg(sum("Final_Price").alias("Total_Price"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_location_wise_sales</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Price</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Branch_Wise_Revenue_Generated"
)
def gold_branch_wise_revenue():
df=dlt.read("customer_sales")
final_df=df.groupBy("Branch_ID").agg(sum("Final_Price").alias("Total_Revenue"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_branch_wise_revenue</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Revenue</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Tags_Wise_Revenue_Generated"
)
def gold_tags_wise_revenue():
df=dlt.read("customer_sales")
final_df=df.groupBy("Branch_ID","Model","Tags").agg(sum("Final_Price").alias("Total_Revenue"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_tags_wise_revenue</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Tags</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Revenue</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Service_Branch_revenue"
)
def gold_service_branch_revenue():
df=dlt.read("customer_service_center")
final_df=df.groupBy("Branch_ID").agg(sum("Total_Price").alias("Total_Revenue"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_service_branch_revenue</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Revenue</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Branch_Wise_Customers"
)
def gold_Branch_Wise_Customers():
df=dlt.read("customer_service_center")
final_df=df.groupBy("Branch_ID").agg(count("customer_id").alias("Total_Customers"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_Branch_Wise_Customers</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Customers</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Location_wise_Customers"
)
def gold_Location_wise_Customers():
df=dlt.read("customer_service_center")
final_df=df.groupBy("Location").agg(count("customer_id").alias("Total_Customers"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_Location_wise_Customers</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Location</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Customers</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(
comment="Branch_wise_Vehicles"
)
def gold_Branch_wise_Vehicles():
df=dlt.read("customer_service_center")
final_df=df.groupBy("Branch_ID","Model").agg(count("Model").alias("total_visits"))
return final_df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_Branch_wise_Vehicles</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Branch_ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Model</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>total_visits</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=4157164815817841#joblist/pipelines/create?initialSource=%2FUsers%2Fmanivallepu%40sateeshaimlgmail.onmicrosoft.com%2Fcreating%20final%20dlt%20pipeline&redirectNotebookId=1609552992568524">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
